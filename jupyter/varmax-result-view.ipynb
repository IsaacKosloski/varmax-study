# %% [markdown]
# #### Objetivo: Plotar os resultados dos melhores modelos dados os hiperparâmetros p,x_lag,real_degree,img_degree

# %%
# ---------------------
# Incluindo Bibliotecas
# ---------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VARMAX
from statsmodels.tsa.stattools import coint,kpss
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from itertools import product,combinations
from git import Repo
import os

# %% [markdown]
# ##### Lendo base de dados

# %%
df_res = pd.read_csv("results/larger-dataset-test-results.csv")
